# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem Statement
#  _Draw an insigh from the Dataset. Write Report under each activity to enhance understanding_.

# %%
sale = pd.read_csv('mySales.csv')
sale
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %% [markdown]
#  ### Simple Analysis

# %%
sale.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  01/11/2014         552
# 1       Offline              C  07/05/2010  301644504   7/26/2010        2167
# 2       Offline              C  09/12/2011  478051030   9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952   6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596   7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
sale.tail()
# Out:
#                             Region      Country   Item Type Sales Channel  \
# 4995         Australia and Oceania  New Zealand   Household       Offline
# 4996  Middle East and North Africa   Azerbaijan     Clothes       Offline
# 4997                          Asia      Myanmar   Baby Food       Offline
# 4998                        Europe      Finland     Clothes        Online
# 4999            Sub-Saharan Africa     Tanzania  Vegetables        Online
#
#      Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 4995              C  04/03/2015  217984473   4/20/2015        5305
# 4996              L   8/17/2014  169748055  10/02/2014        1077
# 4997              H  11/23/2016  226939189  12/10/2016        5204
# 4998              L   4/22/2014  906794202  05/11/2014        9410
# 4999              L  07/08/2011  996861922  08/07/2011        2450
#
#       Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          5000 non-null   object
#  1   Country         5000 non-null   object
#  2   Item Type       5000 non-null   object
#  3   Sales Channel   5000 non-null   object
#  4   Order Priority  5000 non-null   object
#  5   Order Date      5000 non-null   object
#  6   Order ID        5000 non-null   int64
#  7   Ship Date       5000 non-null   object
#  8   Units Sold      5000 non-null   int64
#  9   Unit Price      5000 non-null   float64
#  10  Unit Cost       5000 non-null   float64
#  11  Total Revenue   5000 non-null   float64
#  12  Total Cost      5000 non-null   float64
#  13  Total Profit    5000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 547.0+ KB

# %%
sale.isna()
# Out:
#       Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0      False    False      False          False           False       False
# 1      False    False      False          False           False       False
# 2      False    False      False          False           False       False
# 3      False    False      False          False           False       False
# 4      False    False      False          False           False       False
# ...      ...      ...        ...            ...             ...         ...
# 4995   False    False      False          False           False       False
# 4996   False    False      False          False           False       False
# 4997   False    False      False          False           False       False
# 4998   False    False      False          False           False       False
# 4999   False    False      False          False           False       False
#
# ...

# %%
sale.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
sale.describe()
# Out:
#            Order ID   Units Sold   Unit Price    Unit Cost  Total Revenue  \
# count  5.000000e+03  5000.000000  5000.000000  5000.000000   5.000000e+03
# mean   5.486447e+08  5030.698200   265.745564   187.494144   1.325738e+06
# std    2.594671e+08  2914.515427   218.716695   176.416280   1.475375e+06
# min    1.000909e+08     2.000000     9.330000     6.920000   6.531000e+01
# 25%    3.201042e+08  2453.000000    81.730000    35.840000   2.574168e+05
# 50%    5.523150e+08  5123.000000   154.060000    97.440000   7.794095e+05
# 75%    7.687709e+08  7576.250000   437.200000   263.330000   1.839975e+06
# max    9.998797e+08  9999.000000   668.270000   524.960000   6.672676e+06
#
#          Total Cost  Total Profit
# count  5.000000e+03  5.000000e+03
# mean   9.330932e+05  3.926446e+05
# std    1.150873e+06  3.829351e+05
# min    4.844000e+01  1.687000e+01
# 25%    1.547480e+05  8.533925e+04
# 50%    4.681807e+05  2.790952e+05
# 75%    1.189578e+06  5.651064e+05
# ...

# %%
sale.shape
# Out:
# (5000, 14)

# %%
sale.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
sale.describe(include=['object'])
# Out:
#         Region  Country Item Type Sales Channel Order Priority Order Date  \
# count     5000     5000      5000          5000           5000       5000
# unique       7      185        12             2              4       2305
# top     Europe  Andorra    Fruits       Offline              M  6/26/2010
# freq      1330       40       447          2504           1321          7
#
#          Ship Date
# count         5000
# unique        2320
# top     10/21/2011
# freq             7

# %%
sale['Region'].value_counts().sort_values()
# Out:
# North America                         106
# Australia and Oceania                 416
# Central America and the Caribbean     534
# Middle East and North Africa          610
# Asia                                  719
# Sub-Saharan Africa                   1285
# Europe                               1330
# Name: Region, dtype: int64

# %%
sale['Region'].value_counts().plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
sale['Item Type'].value_counts().sort_values()
# Out:
# Cereal             385
# Clothes            386
# Snacks             398
# Meat               399
# Vegetables         410
# Personal Care      415
# Office Supplies    420
# Household          424
# Cosmetics          424
# Baby Food          445
# Fruits             447
# Beverages          447
# Name: Item Type, dtype: int64

# %%
sale['Item Type'].value_counts().plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
sale['Order Priority']
# Out:
# 0       M
# 1       C
# 2       C
# 3       L
# 4       C
#        ..
# 4995    C
# 4996    L
# 4997    H
# 4998    L
# 4999    L
# Name: Order Priority, Length: 5000, dtype: object

# %%
sale['Order Priority'].value_counts().sort_values()
# Out:
# C    1174
# L    1227
# H    1278
# M    1321
# Name: Order Priority, dtype: int64

# %%
sale['Order Priority'].value_counts().plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
 sale['Sales Channel'].value_counts().sort_values()
# Out:
# Online     2496
# Offline    2504
# Name: Sales Channel, dtype: int64

# %%
sale['Sales Channel'].value_counts().plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
sale['Sales Channel']
# Out:
# 0        Online
# 1       Offline
# 2       Offline
# 3       Offline
# 4       Offline
#          ...
# 4995    Offline
# 4996    Offline
# 4997    Offline
# 4998     Online
# 4999     Online
# Name: Sales Channel, Length: 5000, dtype: object

# %%
sale.head(3)
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  01/11/2014         552
# 1       Offline              C  07/05/2010  301644504   7/26/2010        2167
# 2       Offline              C  09/12/2011  478051030   9/29/2011        4778
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      255.28     159.42      140914.56    87999.84      52914.72
# 1      152.58      97.44      330640.86   211152.48     119488.38
# 2       47.45      31.79      226716.10   151892.62      74823.48

# %% [markdown]
# ### ANALYSING THE FINACIAL ASPECT

# %%
sale['Units Sold']
# Out:
# 0        552
# 1       2167
# 2       4778
# 3       9016
# 4       7542
#         ...
# 4995    5305
# 4996    1077
# 4997    5204
# 4998    9410
# 4999    2450
# Name: Units Sold, Length: 5000, dtype: int64

# %%
sale.head(1)
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  01/11/2014         552
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      255.28     159.42      140914.56    87999.84      52914.72

# %%
X = sale[['Total Cost']]
X
# Out:
#       Total Cost
# 0       87999.84
# 1      211152.48
# 2      151892.62
# 3     1055863.76
# 4      734892.48
# ...          ...
# 4995  2665974.70
# 4996    38599.68
# 4997   829621.68
# 4998   337254.40
# 4999   222778.50
#
# [5000 rows x 1 columns]

# %%
y = sale[['Total Profit']]
y
# Out:
#       Total Profit
# 0         52914.72
# 1        119488.38
# 2         74823.48
# 3        798727.44
# 4        415865.88
# ...            ...
# 4995     879197.65
# 4996      79094.88
# 4997     498855.44
# 4998     691070.40
# 4999     154668.50
#
# [5000 rows x 1 columns]

# %%
y.shape
# Out:
# (5000, 1)

# %%
X.shape
# Out:
# (5000, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train
# Out:
#       Total Cost
# 3035    22384.65
# 3689   214722.63
# 2791  4002295.04
# 2278  1015109.48
# 2073   998020.70
# ...          ...
# 267    228833.77
# 3268   358490.27
# 2853   364902.09
# 1761  4747738.24
# 4871   618035.51
#
# [3500 rows x 1 columns]

# %%
X_test.shape
# Out:
# (1000, 1)

# %%
X_train.shape
# Out:
# (4000, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff (m):', regressor.coef_)
print('Linear Model Coeff (b):', regressor.intercept_)
# Out:
# Linear Model Coeff (m): [[0.26553501]]
# Linear Model Coeff (b): [144956.46113475]
